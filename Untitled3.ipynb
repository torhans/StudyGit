# %%
from sympy.abc import *
from sympy import *
from matplotlib import pyplot as plt
from sympy.plotting import plot3d
init_printing()

# %%
y=Function('y')
dd=diff(sqrt(x**2+0.001*sin(x)**2),x) 
u=Function('u')
eps=Symbol(r'\epsilon')
etha=Function(r'\eta')

# %%
_.subs(y,sin(x))
# Out:
#            d
# x + sin(x)⋅──(sin(x))
#            dx
# ─────────────────────
#      ______________
#     ╱  2      2
#   ╲╱  x  + sin (x)

# %%
simplify(_)
# Out:
#            d
# x + sin(x)⋅──(sin(x))
#            dx
# ─────────────────────
#      ______________
#     ╱  2      2
#   ╲╱  x  + sin (x)

# %%
# %matplotlib notebook

# %%
plot(dd)
plot(sqrt(1+0.001*cos(x)**2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plot3d((sin(x-t)+sin(x+t),(x,-2*pi,2*pi),(t,-1.5*pi,1.5*pi)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
F=Function('F')

# %%
F(x,y(x),diff(y(x),x)).subs(y(x),u(x)+eps*etha(x))
# Out:
#  ⎛                            ∂                          ⎞
# F⎜x, \epsilon⋅\eta(x) + u(x), ──(\epsilon⋅\eta(x) + u(x))⎟
#  ⎝                            ∂x                         ⎠

# %%
_.diff(eps)
# Out:
#         ⎛ ∂ ⎛ ⎛       ∂                          ⎞⎞⎞│
# \eta(x)⋅⎜───⎜F⎜x, ξ₂, ──(\epsilon⋅\eta(x) + u(x))⎟⎟⎟│
#         ⎝∂ξ₂⎝ ⎝       ∂x                         ⎠⎠⎠│ξ₂=\epsilon⋅\eta(x) + u(x
#
#
#     d           ⎛ ∂                                    ⎞│
#   + ──(\eta(x))⋅⎜───(F(x, \epsilon⋅\eta(x) + u(x), ξ₃))⎟│   ∂
# )   dx          ⎝∂ξ₃                                   ⎠│ξ₃=──(\epsilon⋅\eta(x
#                                                             ∂x
#
#
#
# ) + u(x))

# %%
_.collect(etha(x))
# Out:
#         ⎛ ∂ ⎛ ⎛       ∂                          ⎞⎞⎞│
# \eta(x)⋅⎜───⎜F⎜x, ξ₂, ──(\epsilon⋅\eta(x) + u(x))⎟⎟⎟│
#         ⎝∂ξ₂⎝ ⎝       ∂x                         ⎠⎠⎠│ξ₂=\epsilon⋅\eta(x) + u(x
#
#
#     d           ⎛ ∂                                    ⎞│
#   + ──(\eta(x))⋅⎜───(F(x, \epsilon⋅\eta(x) + u(x), ξ₃))⎟│   ∂
# )   dx          ⎝∂ξ₃                                   ⎠│ξ₃=──(\epsilon⋅\eta(x
#                                                             ∂x
#
#
#
# ) + u(x))
