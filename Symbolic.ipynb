# %%
from sympy import *
init_printing()

# %%
x,y,z = symbols("x y z")
f = Function("f")

# %%
deq=Eq(diff(f(x,y),x)+diff(f(x,y),y),x)
deq
# Out:
# ∂             ∂
# ──(f(x, y)) + ──(f(x, y)) = x
# ∂x            ∂y

# %%
psol=pdsolve(deq)
psol
# Out:
#                                    2
#           (x - y)⋅(x + y)   (x + y)
# f(x, y) = ─────────────── + ──────── + F(x - y)
#                  4             8

# %%
F=Function("F")
fsol=solve(Eq(psol.rhs.subs(y,0),x**2),F(x))

# %%
Fs=fsol[0].subs(x,x-y)
Fs
# Out:
#          2
# 5⋅(x - y)
# ──────────
#     8

# %%
sol=simplify(psol.subs(F(x-y),Fs))
sol
# Out:
#                       2
#            2         y
# f(x, y) = x  - x⋅y + ──
#                      2

# %%
# %matplotlib inline
plotting.plot3d(sol.rhs,(x,0,1),(y,0,1))
