# %%
from sympy import *
init_printing()

# %%
x,y,z = symbols("x y z")
f = Function("f")

# %%
deq=Eq(diff(f(x,y),x)+diff(f(x,y),y),x)
deq
# Out:
# ∂             ∂
# ──(f(x, y)) + ──(f(x, y)) = x
# ∂x            ∂y

# %%
psol=pdsolve(deq)
psol
# Out:
#                                    2
#           (x - y)⋅(x + y)   (x + y)
# f(x, y) = ─────────────── + ──────── + F(x - y)
#                  4             8

# %%
beq=Eq(psol.rhs.subs(y,0),1*x**1)
beq
# Out:
#    2
# 3⋅x
# ──── + F(x) = x
#  8

# %%
F=Function("F")
fsol=solve(beq,F(x))
fsol
# Out:
# ⎡x⋅(-3⋅x + 8)⎤
# ⎢────────────⎥
# ⎣     8      ⎦

# %%
Fs=fsol[0].subs(x,x-y)
Fs
# Out:
# (x - y)⋅(-3⋅x + 3⋅y + 8)
# ────────────────────────
#            8

# %%
sol=simplify(psol.subs(F(x-y),Fs))
sol
# Out:
#                      2
#                     y
# f(x, y) = x⋅y + x - ── - y
#                     2

# %%
# %matplotlib inline
plotting.plot3d(sol.rhs,(x,0,1),(y,0,1))

# %%
# %matplotlib inline
plotting.plot3d(sol.rhs.diff(x)+sol.rhs.diff(y)-x,(x,0,1),(y,0,1))

# %%
plotting.plot(sol.rhs.subs(y,0),(x,0,1))
