# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib notebook
x=np.linspace(-10,10,1000)
plt.plot(x,np.abs(x+1)-np.abs(x-1))
# Out:
# <img src="data:image/png;base64,..." width="640">
